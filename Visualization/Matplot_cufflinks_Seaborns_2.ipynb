# %% [markdown]
# Learn about more chart just search on google
#
# i.e. matplotlib plots

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # <font color='blue'>Matplotlib</font>

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### <font color='blue'>Line chart</font>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### <font color='blue'>Area chart</font>

# %%
df.plot(kind='area', alpha=0.4)  #alpha do the color transparency of the chart
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area', alpha=0.9)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area', alpha=0.1)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area', alpha=0.1, stacked = False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### <font color='blue'>Scatter plot</font>

# %%
df.plot.scatter(x='sepal_length', y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x='petal_length', y='petal_width')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
df.plot.scatter(x='petal_length', y='petal_width', c='sepal_width')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
df.plot.scatter(x='sepal_width', y='petal_width', c='sepal_length')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df.plot.scatter(x='sepal_width', y='petal_width', c='sepal_length', s=100)   # increase the size of color
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df.plot.scatter(x='sepal_width', y='petal_width', c='sepal_length', s=1000)   # increase the size of color
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df.plot.scatter(x='sepal_width', y='petal_width', c='sepal_length', s=df['sepal_length']*20)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %% [markdown]
# ### <font color='blue'>Hexbin plot</font>

# %%
df.plot.hexbin(x='sepal_width', y='petal_width', gridsize=20)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df.plot.hexbin(x='sepal_width', y='petal_width', gridsize=20, cmap='viridis')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %% [markdown]
# ### <font color='blue'>3D graph</font>

# %%
from mpl_toolkits import mplot3d

# %%
x = np.linspace(-1,6,30)

# %%
x
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
y = np.linspace(-1,6,30)

# %%
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
z = x+y

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(x,y,z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(df['sepal_length'],df['sepal_width'],df['petal_length'])
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
ax.set_zlabel('petal_length')
# Out:
# Text(0.5, 0, 'petal_length')

# %% [markdown]
# ### <font color='blue'>change the plot chart size</font>

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### <font color='blue'>Bar chart</font>

# %%
df.iloc[5:11].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %%
# bar graph horizontal way

df.iloc[5:11].plot(kind='barh',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### <font color='blue'>Hoistogram Chart</font>

# %%
df.plot(kind='hist',figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['sepal_length'].plot(kind='hist',figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### <font color='brown'>All iris dataset charts through histogram</font>

# %%
df.hist(figsize=(20,10), color ='g', alpha=.9)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %% [markdown]
# # <font color='blue'>Cufflinks library</font>

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.iplot()

# %%
df.iplot(kind='scatter', x='sepal_length',y='sepal_width', mode = 'markers')

# %% [markdown]
# ### <font color='blue'>Bubble Chart</font>

# %%
df.iplot(x='sepal_length',y='sepal_width',size='sepal_length',kind='bubble')

# %%
# 3d bubble chart

df.iplot(x='sepal_length',y='sepal_width',z='petal_length',size='sepal_length',kind='bubble3d')

# %%
df1 = sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.plot(x='total_bill',y='tip',kind='scatter')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df1.iplot(x='total_bill',y='tip',kind='scatter',mode='markers')

# %% [markdown]
# # <font color='blue'>Seaborn library</font>

# %%
sns.relplot(x='total_bill',y='tip',data=df1)

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# create a chart find out, how many are smoker and non-smoker

df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='smoker')   # by default it will take kind='scatter'

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='time',style='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='time',style='sex')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='sex')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='size',style='size')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,col='time')

# %%
sns.relplot(x='sepal_length',y='sepal_width',data=df,col='species')

# %%
# which day customers are coming in the resturant

sns.relplot(x='total_bill',y='tip',data=df1,col='day')

# %%
sns.catplot(x='day',y='total_bill',data=df1)

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df)

# %%
df.scatter_matrix()   # same as a upper cell

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots()

ax.hist(x, bins=8, linewidth=0.5, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots()

ax.hist(df['sepal_length'], bins=8, linewidth=0.5, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()

# %% [markdown]
# ### <font color='blue'>Joint plot of scatter and histogram plot</font>

# %%
sns.jointplot(x=df1.total_bill,y=df1.tip)

# %%
sns.jointplot(x=df1.total_bill,y=df1.tip,kind='hex')

# %% [markdown]
# ### <font color='blue'>linear regression</font>

# %%
sns.regplot(x=df1.total_bill,y=df1.tip)
sns.set(rc={'figure.figsize':(11.7,8.27)})   # to set figure size

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Load the example car crash dataset
crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total", y="abbrev", data=crashes,
            label="Total", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="alcohol", y="abbrev", data=crashes,
            label="Alcohol-involved", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="upper left", frameon=True)
ax.set(xlim=(0, 24), ylabel="country",xlabel="Automobile collisions per billion miles")
sns.despine(left=True, bottom=True)

# %%
sns.load_dataset("car_crashes")
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
import plotly.express as px

fig = px.scatter(df1, x="total_bill", y="tip", color="time")
fig.show()

# %%
import plotly.express as px

fig = px.bar(df1, x="sex", y="total_bill", color="smoker", barmode="group")
fig.show()

# %% [markdown]
# # Chart library Github links
#
# cufflinks - https://github.com/santosjorge/cufflinks
#
# plotly - https://plotly.com/python/plotly-express/
#
# seaborn - https://seaborn.pydata.org/index.html
#
# matplotlib - https://matplotlib.org/stable/index.html
